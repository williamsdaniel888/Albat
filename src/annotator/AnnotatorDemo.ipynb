# %%
# %%shell
# gdown https://drive.google.com/uc?id=1bI_bH52QTHHnLgvOd6a2rjldhVPLdLCg # annotator.py
# gdown https://drive.google.com/uc?id=1tG-KHdt-kuVfoMXN7RoRPhFwRtXb8pPw # absa_data_utils.py
# gdown https://drive.google.com/uc?id=1ql_DHQ9o1zvNCWNqFYrdvSHrq5FtLPnO # test.json (MAMS)
# gdown https://drive.google.com/uc?id=1nFPD6V8lkF1ZBQoVo2q9DcKrf77huDvV # predictions1lc.json (Albat-1LC E2E-ABSA MAMS)
# gdown https://drive.google.com/uc?id=1G5nhlhr_teKp8XV0f9nwF_nR137pJ6_W # predictions2lc.json (Albat-2LC E2E-ABSA MAMS)
# gdown https://drive.google.com/uc?id=11qF9HtLmQ5rcjUMvNtaU5H8clL1c0lIV # predictions3lc.json (Albat-3LC E2E-ABSA MAMS)
#
# pip install transformers
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1bI_bH52QTHHnLgvOd6a2rjldhVPLdLCg
# To: /content/annotator.py
# 100% 3.69k/3.69k [00:00<00:00, 7.18MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1tG-KHdt-kuVfoMXN7RoRPhFwRtXb8pPw
# To: /content/absa_data_utils.py
# 100% 13.9k/13.9k [00:00<00:00, 23.0MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1ql_DHQ9o1zvNCWNqFYrdvSHrq5FtLPnO
# To: /content/test.json
# 100% 568k/568k [00:00<00:00, 37.8MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1nFPD6V8lkF1ZBQoVo2q9DcKrf77huDvV
# To: /content/predictions1lc.json
# 18.6MB [00:00, 59.1MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1G5nhlhr_teKp8XV0f9nwF_nR137pJ6_W
# To: /content/predictions2lc.json
# 18.6MB [00:00, 70.4MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=11qF9HtLmQ5rcjUMvNtaU5H8clL1c0lIV
# To: /content/predictions3lc.json
# 18.6MB [00:00, 59.2MB/s]
# ...
#      |████████████████████████████████| 778kB 2.8MB/s
# ...

# %%
import sys
if 'annotator' not in sys.modules:
    import annotator
else:
    import importlib
    importlib.reload(annotator)

# File path for Albat's E2E test set predictions (predictions{1,2,3}lc.json)
predictions = "./predictions1lc.json"

# Directory path containing ground truth labels for test set (test.json)
# Make sure this is the same dataset used by Albat
truth = "./"

# Choose the review index to display
review_id = 0

annotator.extractor(review_id,predictions,truth)
# Out:
# ...
# EXAMPLE #0
#
# Color key:
# Non-aspect word: [black on white]
# Positive:  beginning, inside.
# Negative:  beginning, inside.
# Neutral:   beginning, inside.
# Conflict:  beginning, inside.
#
# True labeling scheme:
#
# ▁the▁food▁was▁served▁promptly▁but▁the▁meal▁wasn▁'▁t▁rushed▁-
# ▁we▁had▁plenty▁of▁time▁to▁enjoy▁the▁appetizers▁and▁our▁entre
# es▁as▁well▁as▁sit▁and▁chat▁while▁finishing▁up▁our▁drinks▁even
# ▁after▁we▁paid▁.
#
# Labels predicted by Albat-1LC:
#
# ▁the▁food▁was▁served▁promptly▁but▁the▁meal▁wasn▁'▁t▁rushed▁-
# ▁we▁had▁plenty▁of▁time▁to▁enjoy▁the▁appetizers▁and▁our▁entre
# es▁as▁well▁as▁sit▁and▁chat▁while▁finishing▁up▁our▁drinks▁even
# ▁after▁we▁paid▁.
#
# CONFUSION MATRIX:
